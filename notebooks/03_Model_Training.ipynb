# %% [markdown]
# # Model Training
# Train Logistic Regression, Naive Bayes, and Linear SVM with TF-IDF features.

# %%
import sys
sys.path.append("..")
import pandas as pd
from src.model.trainer import train_models

data = pd.read_csv("../data/raw/sentiment.csv")
models, vectorizer = train_models(data["text"], data["sentiment"])
print(list(models))
print(f"TF-IDF features: {len(vectorizer.get_feature_names_out())}")
