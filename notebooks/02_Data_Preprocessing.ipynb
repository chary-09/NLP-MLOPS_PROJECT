# %% [markdown]
# # Data Preprocessing
# Clean the text and inspect the tokens used by the model.

# %%
import sys
sys.path.append("..")
import pandas as pd
from src.nlp.preprocessor import clean_text
from src.nlp.tokenizer import tokenize

data = pd.read_csv("../data/raw/sentiment.csv")
data["clean_text"] = data["text"].map(clean_text)
data["tokens"] = data["text"].map(tokenize)
data[["text", "clean_text", "tokens"]]
